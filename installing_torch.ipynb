# %% [markdown]
# <a href="https://colab.research.google.com/github/Cunyie08/AI-Engineering-Program__Python/blob/master/installing_torch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchaudio torchvision --quiet

# %%
import torch

# %%
torch.__version__
# Out:
# '2.8.0+cu126'

# %%
torch.cuda.is_available()
# Out:
# False
